# %% [markdown]
# # 単線形回帰　課題の解答

# %% [markdown]
# 以下のコードを書きましょう:
# -  散布図を作成しましょう
# -  決定係数を計算しましょう
# -  係数と切片を表示しましょう
# -  面積が750の場合における価格を予測しましょう

# %% [markdown]
# ## ライブラリのインポート

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## データの読み込み

# %%
data = pd.read_csv("../../data/exercise/real_estate_price_size.csv")

# %%
data
# Out:
#          price     size
# 0   234314.144   643.09
# 1   228581.528   656.22
# 2   281626.336   487.29
# 3   401255.608  1504.75
# 4   458674.256  1275.46
# ..         ...      ...
# 95  252460.400   549.80
# 96  310522.592  1037.44
# 97  383635.568  1504.75
# 98  225145.248   648.29
# 99  274922.856   705.29
#
# [100 rows x 2 columns]

# %% [markdown]
# ## 回帰の作成

# %% [markdown]
# ### 従属変数と独立変数の作成

# %%
x = data["size"]
y = data["price"]

# %% [markdown]
# ### データの確認

# %% [markdown]
# ### 入力データの形状の変更

# %%
x_matrix = x.values.reshape(-1, 1)

# %% [markdown]
# ### 回帰

# %%
reg = LinearRegression()
reg.fit(x_matrix, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### 決定係数の計算

# %%
reg.score(x_matrix, y), reg.coef_, reg.intercept_
# Out:
# (0.7447391865847587, array([223.17874259]), 101912.601801229)

# %% [markdown]
# ### 係数の表示

# %% [markdown]
# ### 切片の表示

# %% [markdown]
# ### 予測

# %%
reg.predict([[750]])
# Out:
# array([269296.65874718])
